# %% [markdown]
# <a href="https://colab.research.google.com/github/Anagefilho/UFU_Mestrado/blob/main/atividade_02_an_lise_de_imagens.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##  <font style="color:black">**Atividade 02**</font>
#
# Faça um programa que ao abrir a câmera do seu computador, salve a foto da sua equipe. Salve as imagens da equipe pelo software. E por fim, ao final insira nome deles na imagem com OpenCV.
#
# ## Material de apoio
#
# https://www.askpython.com/python-modules/opencv-puttext
#
# https://machinelearningknowledge.ai/put-text-on-image-in-opencv-python-using-cv2-puttext-with-examples/

# %% [markdown]
# ## Importando bibliotecas.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode
from google.colab.patches import cv2_imshow

# %% [markdown]
# ## Acesso a câmera do notebook.

# %%
def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename

# %% [markdown]
# ## Tirando a foto - Angélica

# %%
from IPython.display import Image
try:
  filename = take_photo()
  print('Saved to {}'.format(filename))
  
  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))
# Out:
# Saved to photo.jpg

# %% [markdown]
# ## Escrevendo o nome na foto - Angélica.

# %%
# lendo a imagem
image = cv2.imread("photo.jpg")
 
# Utilizando cv2.putText()
new_image = cv2.putText(
  img = image,
  text = "Angelica Gomes Oliveira", #Nome que ficará na foto
  org = (25, 50), #local onde a letra ficará, onde 2 é o valor do x e 50 o valor do y
  fontFace = cv2.FONT_HERSHEY_PLAIN, #escolhendo a fonte da letra
  fontScale = 3.0, #tamanho da fonte
  color = (125, 246, 55), #cor da fonte
  thickness = 3 #espessura da letra 
)
 
# Salvando a imagem
cv2.imwrite("angelica.jpg", new_image)
# Out:
# True

# %%
foto_retirada = cv2.imread('angelica.jpg')
cv2_imshow(foto_retirada)
plt.imshow(foto_retirada)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F71A1AEBCD0>

# %% [markdown]
# ## Tirando a foto - Anagê

# %%
from IPython.display import Image
try:
  filename = take_photo()
  print('Saved to {}'.format(filename))
  
  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))
# Out:
# Saved to photo.jpg

# %% [markdown]
# ## Escrevendo o nome na foto - Anagê.

# %%
# lendo a imagem
image = cv2.imread("photo.jpg")
 
# Utilizando cv2.putText()
new_image = cv2.putText(
  img = image,
  text = "Anage Filho", #Nome que ficará na foto
  org = (25, 50), #local onde a letra ficará, onde 2 é o valor do x e 50 o valor do y
  fontFace = cv2.FONT_HERSHEY_PLAIN, #escolhendo a fonte da letra
  fontScale = 3.0, #tamanho da fonte
  color = (125, 246, 55), #cor da fonte
  thickness = 3 #espessura da letra 
)
 
# Salvando a imagem
cv2.imwrite("anage.jpg", new_image)
# Out:
# True

# %%
foto_retirada = cv2.imread('anage.jpg')
cv2_imshow(foto_retirada)
plt.imshow(foto_retirada)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F648415D350>

# %% [markdown]
# ## Tirando a foto - Lorena

# %%
from IPython.display import Image
try:
  filename = take_photo()
  print('Saved to {}'.format(filename))
  
  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))
# Out:
# Saved to photo.jpg

# %% [markdown]
# ## Escrevendo o nome na foto - Lorena.

# %%
# lendo a imagem
image = cv2.imread("photo.jpg")
 
# Utilizando cv2.putText()
new_image = cv2.putText(
  img = image,
  text = "Lorena Ferreira Marani", #Nome que ficará na foto
  org = (25, 50), #local onde a letra ficará, onde 2 é o valor do x e 50 o valor do y
  fontFace = cv2.FONT_HERSHEY_PLAIN, #escolhendo a fonte da letra
  fontScale = 3.0, #tamanho da fonte
  color = (125, 246, 55), #cor da fonte
  thickness = 3 #espessura da letra 
)
 
# Salvando a imagem
cv2.imwrite("lorena.jpg", new_image)
# Out:
# True

# %%
foto_retirada = cv2.imread('lorena.jpg')
cv2_imshow(foto_retirada)
plt.imshow(foto_retirada)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7FC9CE1DB2D0>
